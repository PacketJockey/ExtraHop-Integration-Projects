# %%
import requests
import json

# %%
#AlienVault API send OTD PULSE Indicators to External Data

headers = {'Accept': 'application/json',
           'X-OTX-API-KEY': '713a2bc760dfcf0919104496ee47d0839a3be77ff9c5e6c5c7f6d762d7c53740'
           
          }
################# Active Bedep DGA(s) for 20200430 ############################
#endpoint = 'https://otx.alienvault.com/api/v1/pulses/5eab656cf2008f007c52a387/'
################# Basic COVID19 Domain Jackassery #############################
#endpoint = 'https://otx.alienvault.com/api/v1/pulses/5eaca43f181063497eb90182'
################# Ryuk Covid19 Domain Ransomware ##############################
endpoint = 'https://otx.alienvault.com/api/v1/pulses/5e8756377b956df7647cf034'
r = requests.get(endpoint, headers=headers, verify=False)

output_dict = [x for x in r.json()['indicators'] if x['type'] == 'URL' 
                                                 or x['type'] == 'domain'
                                                 or x['type'] == 'hostname'
                                                 or x['type'] == 'IPv4' ]
output_dict

################### Utilities ######################
#r.json()['name']                                  # 
#r.json()                                          # 
#for indicator in r.json()['indicators']:          # 
#    print (indicator['indicator'])                # 
####################################################
# Out:
# [{u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331335,
#   u'indicator': u'fiuugiv.cn',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331336,
#   u'indicator': u'killdesctidogli.ga',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331337,
#   u'indicator': u'codev.design',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331338,
#   u'indicator': u'spachymlise.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2205075085,
#   u'indicator': u'ourtct.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331339,
#   u'indicator': u'mukutdivetioman.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2202634477,
#   u'indicator': u'iexploreservice.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331340,
#   u'indicator': u'telecharger-zeros.fr',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2222875780,
#   u'indicator': u'vintagepizzamenu.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331341,
#   u'indicator': u'quotweetabanun.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331342,
#   u'indicator': u'covid-maker.ovh',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331343,
#   u'indicator': u'pengxiang.me',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331344,
#   u'indicator': u'simonisacoder.cn',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331345,
#   u'indicator': u'quidunmoofabo.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331346,
#   u'indicator': u'2spicypeppers.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331347,
#   u'indicator': u'cornerofthai-whittlesea.com.au',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331348,
#   u'indicator': u'itbrain.ml',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331349,
#   u'indicator': u'jnjava.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331350,
#   u'indicator': u'fuck12.club',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331351,
#   u'indicator': u'anabdebo.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231294414,
#   u'indicator': u'webdesignbomb.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331352,
#   u'indicator': u'karencherry.site',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331353,
#   u'indicator': u'025lsfcjf.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331354,
#   u'indicator': u'acmymontpanli.ml',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331355,
#   u'indicator': u'diemigpancti.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331356,
#   u'indicator': u'resdegargia.ga',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331357,
#   u'indicator': u'hubs-play.in.ua',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331358,
#   u'indicator': u'themrh.ir',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331359,
#   u'indicator': u'riztepahopot.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331360,
#   u'indicator': u'planosdesaudesp.online',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331361,
#   u'indicator': u'borkservice-msk.ru',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331362,
#   u'indicator': u'pain666.club',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331363,
#   u'indicator': u'recoterro.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331364,
#   u'indicator': u'nates.website',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331365,
#   u'indicator': u'inrionote.ga',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331366,
#   u'indicator': u'efexchangeyear.co.uk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2221806612,
#   u'indicator': u'lookdesign.club',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331367,
#   u'indicator': u'ziven.cc',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331368,
#   u'indicator': u'mirtalpur.me',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331369,
#   u'indicator': u'guteweb.net',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331370,
#   u'indicator': u'eromanga-yoru.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331371,
#   u'indicator': u'namelesshvh.xyz',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331372,
#   u'indicator': u'happyfathersdayquotesv.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331373,
#   u'indicator': u'classcards.club',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331374,
#   u'indicator': u'insureadvisor.in',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331375,
#   u'indicator': u'pware.xyz',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2119116870,
#   u'indicator': u'diadospaicasasbahia.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331376,
#   u'indicator': u'goszakupcentr.kz',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331377,
#   u'indicator': u'rabnighsenga.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331378,
#   u'indicator': u'onachniamarg.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331379,
#   u'indicator': u'xgame.best',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331380,
#   u'indicator': u'nameless.pub',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331381,
#   u'indicator': u'namibiasmes.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331382,
#   u'indicator': u'plecajwissades.tk',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331383,
#   u'indicator': u'redlandserver.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331384,
#   u'indicator': u'wamiticme.cf',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 232430656,
#   u'indicator': u'zk74.cn',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331385,
#   u'indicator': u'hanoverwestuniversity.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'domain'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331461,
#   u'indicator': u'http://iexploreservice.com/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331462,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/film+pr%C3%A9dator.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331463,
#   u'indicator': u'http://members.lambirides.in/member/mail/options',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331464,
#   u'indicator': u'http://jettrain.icu/mmghtdjvmp/xckmru110241rrdupeoab',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331465,
#   u'indicator': u'http://jettrain.icu/Gky5zxbhu/yHFP0q1RymYAB3CAg6KC7L1lfC3eNCFZflHeGsj60UA',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331466,
#   u'indicator': u'https://xgame.best/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331467,
#   u'indicator': u'http://telecharger-zeros.fr/tags/Vanessa+Marshall',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331468,
#   u'indicator': u'http://jettrain.icu/Qvjkgxwcp/rdksq110241tmjqnc',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331469,
#   u'indicator': u'https://eromanga-yoru.com/netorare-netori/4509',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331470,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E3%81%BF%E3%81%A1%E3%81%8D%E3%82%93%E3%81%90',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331471,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E7%88%BA%E3%82%8F%E3%82%89',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331472,
#   u'indicator': u'http://borkservice-msk.ru/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331473,
#   u'indicator': u'https://2spicypeppers.com/wp/wp-admin/signin/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331474,
#   u'indicator': u'http://goszakupcentr.kz/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331475,
#   u'indicator': u'http://iexploreservice.com/s/ref=nb_sb_noss_1/167-3294888-0262949/field-keywords=books',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331476,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/film+sur+enlevement.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331477,
#   u'indicator': u'http://telecharger-zeros.fr/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331478,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/film+oscar+louis+de+funes.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331479,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E5%B2%A9%E5%B4%8E%E3%83%A6%E3%82%A6%E3%82%AD',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331480,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/le+festin+de+babeth.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331481,
#   u'indicator': u'http://jettrain.icu/Qvurc/whadeqa110241mjkx',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331482,
#   u'indicator': u'https://eromanga-yoru.com/category/netorare-netori',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331483,
#   u'indicator': u'http://telecharger-zeros.fr/tags/Andre+Braugher',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331484,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/le+petit+loup+garou.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331485,
#   u'indicator': u'http://members.lambirides.in/Member/Media',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331486,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/sao+s1+vf.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331487,
#   u'indicator': u'https://www.maryestherumc.org/wp-content/plugins/google-calendar-events/assets/js/vendor/imagesloaded.pkgd.min.js?ver=3.1.22',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331488,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/penthere+rose.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331489,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/les+contes+de+la+nuit+film.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331490,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E3%81%95%E3%81%84%E3%82%82%E3%82%93',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331491,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/naruto+159+vf.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2119116979,
#   u'indicator': u'http://diadospaicasasbahia.com/fralda-pampers-confort-sec-mega-g-kit-com-152-unidades/system/seguranca9/8XMOOPewj7ZtJbxoQmqV.php',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331492,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E7%88%86%E4%B9%B3',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331493,
#   u'indicator': u'http://namibiasmes.com/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331494,
#   u'indicator': u'https://eromanga-yoru.com/tag/%E6%B7%AB%E4%B9%B1%E3%83%BB%E3%83%93%E3%83%83%E3%83%81',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331495,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/harry+potter+dernier.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331496,
#   u'indicator': u'https://eromanga-yoru.com/...',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331497,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/dragon+ball+z+ddl.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331498,
#   u'indicator': u'https://eromanga-yoru.com/onesyota/17011',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331499,
#   u'indicator': u'http://jnjava.com/',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331500,
#   u'indicator': u'http://telecharger-zeros.fr/recherche/les+meilleurs+films+3d.html',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331501,
#   u'indicator': u'https://eromanga-yoru.com/category/eromanga-night',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331502,
#   u'indicator': u'http://www.jettrain.icu/fbrbf/cvBfGEqh_2ydEhSHz-bktvsUzJsGPQlzKB4eR5NAz_E5iq78c_n7yYDBXZUWwjKNv45Ft-BjZYMe8E2vbyabmC_BSTwRsQ1vCLS6SWekyHAun33LNs1ApNj0hxxqeidL.oNauzuBZ7SQ5EJDAE79IyQxwkhk9G2N4kJ6ju7FYVf5',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'URL'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331503,
#   u'indicator': u'mail.rop.nl',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331504,
#   u'indicator': u'lottery-staging.maltcodemo.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331505,
#   u'indicator': u'echo.liansixin.win',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331506,
#   u'indicator': u'api.chenyueban.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331507,
#   u'indicator': u'www.randommacguy.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331508,
#   u'indicator': u'www.disposablefacemask.shop',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331509,
#   u'indicator': u'members.lambirides.in',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331510,
#   u'indicator': u'test.kunam.fi',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331511,
#   u'indicator': u'www.maryestherumc.org',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331512,
#   u'indicator': u'www.mexgroup.asia',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331513,
#   u'indicator': u'cpcalendars.mattagamidrum.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331535,
#   u'indicator': u'polsi.caterad.press',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331536,
#   u'indicator': u'www.chenyueban.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331537,
#   u'indicator': u'blog.aaronjs.me',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331538,
#   u'indicator': u'www.alcootestenligne.fr',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'MX Server',
#   u'expiration': None,
#   u'id': 2231331539,
#   u'indicator': u'mx.containcoronavirus.tech',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331540,
#   u'indicator': u'www.happyramadanquotes2015.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331541,
#   u'indicator': u'cpcontacts.mattagamidrum.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331542,
#   u'indicator': u'blog.chenyueban.com',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': None,
#   u'id': 2231331543,
#   u'indicator': u'www.jettrain.icu',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'hostname'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331544,
#   u'indicator': u'149.28.231.162',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331545,
#   u'indicator': u'192.30.255.153',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331546,
#   u'indicator': u'192.30.255.154',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331547,
#   u'indicator': u'120.79.133.48',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2202634476,
#   u'indicator': u'95.179.215.228',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331548,
#   u'indicator': u'104.27.170.9',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 2231331549,
#   u'indicator': u'104.27.171.9',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'},
#  {u'content': u'',
#   u'created': u'2020-04-03T15:28:56',
#   u'description': u'',
#   u'expiration': u'2020-05-03T00:00:00',
#   u'id': 1659122877,
#   u'indicator': u'185.199.110.153',
#   u'is_active': 1,
#   u'title': u'',
#   u'type': u'IPv4'}]

# %%
data = output_dict 
descr = r.json()['name']
for indicator in data:
    req = {
    "body": {"field": indicator['indicator'] ,"Description": descr},    
    "type": "OTX-Intel"    
    }
    req_body = json.dumps(req)
    print(req_body)
    headers = {'Content-Type': 'application/json',
           'Accept': 'application/json',
           #'Authorization': 'ExtraHop apikey=yoFGLks2F9heUg2lERhDktR7AsiR9o3BKdB7U-Gnh9Y'
           'Authorization': 'ExtraHop apikey=XEMtosy0PVTt__IyjWgEjl1KGWU5hO9mDA6z6h9o8J0'
              }
    #endpoint = 'https://172.16.178.131/api/v1/triggers/externaldata'
    endpoint = 'https://100.26.82.150/api/v1/triggers/externaldata'
    r = requests.post(endpoint, headers=headers, data=req_body ,verify=False)
    #r
# Out:
# {"body": {"field": "fiuugiv.cn", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "killdesctidogli.ga", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "codev.design", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "spachymlise.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "ourtct.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "mukutdivetioman.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "iexploreservice.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "telecharger-zeros.fr", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "vintagepizzamenu.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "quotweetabanun.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "covid-maker.ovh", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "pengxiang.me", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "simonisacoder.cn", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "quidunmoofabo.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "2spicypeppers.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "cornerofthai-whittlesea.com.au", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "itbrain.ml", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "jnjava.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "fuck12.club", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "anabdebo.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "webdesignbomb.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "karencherry.site", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "025lsfcjf.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "acmymontpanli.ml", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "diemigpancti.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "resdegargia.ga", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "hubs-play.in.ua", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "themrh.ir", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "riztepahopot.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "planosdesaudesp.online", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "borkservice-msk.ru", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "pain666.club", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "recoterro.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "nates.website", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "inrionote.ga", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "efexchangeyear.co.uk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "lookdesign.club", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "ziven.cc", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "mirtalpur.me", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "guteweb.net", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "eromanga-yoru.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "namelesshvh.xyz", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "happyfathersdayquotesv.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "classcards.club", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "insureadvisor.in", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "pware.xyz", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "diadospaicasasbahia.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "goszakupcentr.kz", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "rabnighsenga.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "onachniamarg.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "xgame.best", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "nameless.pub", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "namibiasmes.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "plecajwissades.tk", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "redlandserver.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "wamiticme.cf", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "zk74.cn", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "hanoverwestuniversity.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://iexploreservice.com/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/film+pr%C3%A9dator.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://members.lambirides.in/member/mail/options", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://jettrain.icu/mmghtdjvmp/xckmru110241rrdupeoab", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://jettrain.icu/Gky5zxbhu/yHFP0q1RymYAB3CAg6KC7L1lfC3eNCFZflHeGsj60UA", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://xgame.best/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/tags/Vanessa+Marshall", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://jettrain.icu/Qvjkgxwcp/rdksq110241tmjqnc", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/netorare-netori/4509", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E3%81%BF%E3%81%A1%E3%81%8D%E3%82%93%E3%81%90", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E7%88%BA%E3%82%8F%E3%82%89", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://borkservice-msk.ru/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://2spicypeppers.com/wp/wp-admin/signin/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://goszakupcentr.kz/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://iexploreservice.com/s/ref=nb_sb_noss_1/167-3294888-0262949/field-keywords=books", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/film+sur+enlevement.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/film+oscar+louis+de+funes.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E5%B2%A9%E5%B4%8E%E3%83%A6%E3%82%A6%E3%82%AD", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/le+festin+de+babeth.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://jettrain.icu/Qvurc/whadeqa110241mjkx", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/category/netorare-netori", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/tags/Andre+Braugher", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/le+petit+loup+garou.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://members.lambirides.in/Member/Media", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/sao+s1+vf.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://www.maryestherumc.org/wp-content/plugins/google-calendar-events/assets/js/vendor/imagesloaded.pkgd.min.js?ver=3.1.22", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/penthere+rose.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/les+contes+de+la+nuit+film.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E3%81%95%E3%81%84%E3%82%82%E3%82%93", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/naruto+159+vf.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://diadospaicasasbahia.com/fralda-pampers-confort-sec-mega-g-kit-com-152-unidades/system/seguranca9/8XMOOPewj7ZtJbxoQmqV.php", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E7%88%86%E4%B9%B3", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://namibiasmes.com/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/tag/%E6%B7%AB%E4%B9%B1%E3%83%BB%E3%83%93%E3%83%83%E3%83%81", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/harry+potter+dernier.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/...", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/dragon+ball+z+ddl.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/onesyota/17011", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://jnjava.com/", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://telecharger-zeros.fr/recherche/les+meilleurs+films+3d.html", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "https://eromanga-yoru.com/category/eromanga-night", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "http://www.jettrain.icu/fbrbf/cvBfGEqh_2ydEhSHz-bktvsUzJsGPQlzKB4eR5NAz_E5iq78c_n7yYDBXZUWwjKNv45Ft-BjZYMe8E2vbyabmC_BSTwRsQ1vCLS6SWekyHAun33LNs1ApNj0hxxqeidL.oNauzuBZ7SQ5EJDAE79IyQxwkhk9G2N4kJ6ju7FYVf5", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "mail.rop.nl", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "lottery-staging.maltcodemo.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "echo.liansixin.win", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "api.chenyueban.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.randommacguy.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.disposablefacemask.shop", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "members.lambirides.in", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "test.kunam.fi", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.maryestherumc.org", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.mexgroup.asia", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "cpcalendars.mattagamidrum.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "polsi.caterad.press", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.chenyueban.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "blog.aaronjs.me", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.alcootestenligne.fr", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "mx.containcoronavirus.tech", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.happyramadanquotes2015.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "cpcontacts.mattagamidrum.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "blog.chenyueban.com", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "www.jettrain.icu", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "149.28.231.162", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "192.30.255.153", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "192.30.255.154", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "120.79.133.48", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "95.179.215.228", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "104.27.170.9", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "104.27.171.9", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}
# {"body": {"field": "185.199.110.153", "Description": "Ryuk Ransomware Campaign using Covid19 Domains"}, "type": "OTX-Intel"}

# %%
######################################
# Practice area to dump/observe JSON #
######################################

# %%
headers = {'Accept': 'application/json',
           'X-OTX-API-KEY': '713a2bc760dfcf0919104496ee47d0839a3be77ff9c5e6c5c7f6d762d7c53740' 
          }
#endpoint = 'https://otx.alienvault.com/api/v1/pulses/5eab656cf2008f007c52a387/'
endpoint = 'https://otx.alienvault.com/api/v1/pulses/5eaca43f181063497eb90182'

r = requests.get(endpoint, headers=headers, verify=False)
r.json()['description']
#data = r.json()["indicators"]
# Out:
# u"Our team compiled a list of these domain names from our Newly Registered Domains feed that can be used to protect your family, employees and customers. The list is based solely on the domain names' and registration timeframe, no other assumptions are made. The information is provided as-is, with no warranties. For our Enterprise Threat Data services, please visit https://malwarepatrol.net/ or contact us at commercial@malwarepatrol.net."
